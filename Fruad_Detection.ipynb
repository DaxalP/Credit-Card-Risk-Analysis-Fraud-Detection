# %%
import pandas as pd
df = pd.read_csv('Dataset.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
from matplotlib import pyplot as plt
df['Amount'].hist(bins=50)
plt.show()

# %%
from sklearn.preprocessing import RobustScaler
new_df = df.copy()
new_df['Amount'] = RobustScaler().fit_transform(new_df['Amount'].to_numpy().reshape(-1, 1))
time = new_df['Time']
new_df['Time'] = (time - time.min()) / (time.max() - time.min())
new_df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0       0.000000  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1       0.000000   1.191857   0.266151  0.166480  0.448154  0.060018
# 2       0.000006  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3       0.000006  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4       0.000012  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  0.999965 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  0.999971  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  0.999977   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  0.999977  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  1.000000  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  1.783274
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.269825
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  4.983721
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  1.418291
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153  0.670579
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731 -0.296653
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527  0.038986
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561  0.641096
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533 -0.167680
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  2.724796
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
from matplotlib import pyplot as plt
new_df['Class'].value_counts().plot(kind='bar', title='Class Distribution')
plt.show()

# %%
import seaborn as sns

sns.heatmap(new_df.corr(), cmap='coolwarm', annot=False, fmt='.2f')
# Out:
# <Axes: >

# %%
new_df = new_df.sample(frac=1, random_state=1)
new_df
# Out:
#             Time        V1         V2        V3        V4         V5  \
# 79394   0.335698  1.297904   0.043872  0.009486  0.247843  -0.006953
# 234060  0.855427 -3.454268   0.939446 -3.998022  0.364151  -0.042234
# 88697   0.360260 -0.524164  -0.516659  2.560737  0.030273  -1.595964
# 195482  0.758600  1.913035   0.444965 -2.482750  0.600412   1.180905
# 78321   0.332625 -6.423197   1.072629 -3.820238 -0.269845  -4.125205
# ...          ...       ...        ...       ...       ...        ...
# 281523  0.985208  1.721601   0.560128 -1.514416  3.790465   1.416996
# 84672   0.349617  1.304349  -0.788838  0.937168 -0.298653  -1.548985
# 9027    0.072845 -5.708411   4.794625 -1.155486  0.421606  -0.588195
# 220124  0.821994 -0.847203   1.208491  0.499767 -0.854787   1.199602
# 4235    0.021720 -7.955978 -10.773199  1.833876  0.612396  10.421777
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 79394  -0.041165 -0.181796  0.113385  0.124404  ... -0.302000 -0.987028
# 234060 -2.524825 -0.306520  0.924521  0.150267  ...  0.126650  0.817265
# 88697   0.899283 -0.397618  0.197104 -0.587595  ...  0.219752  0.722938
# 195482 -0.248702  0.135888  0.030653  0.471372  ...  0.185071  0.859973
# 78321  -0.690805 -0.196968  2.840871 -0.307457  ...  0.011082  0.109586
# ...          ...       ...       ...       ...  ...       ...       ...
# 281523  2.239109 -0.814407  0.865376 -0.410357  ...  0.101529  0.391878
# 84672  -0.482346 -0.911293 -0.036551 -0.094390  ... -0.309873 -0.232419
# 9027    1.152312 -1.428505 -6.065001  3.783663  ...  5.441096 -0.955916
# 220124 -0.601743  1.014615  0.029374 -0.913572  ...  0.168787  0.505289
# 4235   -5.939790 -7.267740  1.148789  0.585934  ...  0.648564 -1.301176
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 79394   0.000210 -0.889473  0.285051  0.155191 -0.045627 -0.006632 -0.279746
# 234060 -0.648714  0.219970  0.234361  1.019397 -0.198642 -0.176424 -0.118773
# 88697  -0.035164 -0.034385  0.301716  0.189905  0.114639  0.098380  1.788584
# 195482  0.038084 -1.242674  0.036824 -0.003165  0.074703 -0.003435 -0.293440
# 78321  -0.041425  0.576822 -0.291755  0.837947 -0.077805 -0.788987  3.259973
# ...          ...       ...       ...       ...       ...       ...       ...
# 281523  0.141820 -1.273417 -0.365048  0.160982  0.079434  0.012613 -0.149375
# 84672  -0.018072  0.431266  0.281028  0.952900 -0.006231  0.019126  0.041920
# 9027    1.007934  0.045643 -1.318965 -0.915560 -5.045247  0.211421 -0.293440
# 220124 -0.574235  0.725967  0.915768  0.771751  0.195432  0.123289 -0.263397
# 4235    1.739646 -1.849254  0.810815 -0.484609 -0.381375  0.238919  0.091665
#
#         Class
# 79394       0
# 234060      0
# 88697       0
# 195482      0
# 78321       0
# ...       ...
# 281523      0
# 84672       0
# 9027        0
# 220124      0
# 4235        0
#
# [284807 rows x 31 columns]

# %%
train, test, val = new_df[:240000], new_df[240000:262000], new_df[262000:]
train['Class'].value_counts(), test['Class'].value_counts(), val['Class'].value_counts()
# Out:
# (Class
#  0    239577
#  1       423
#  Name: count, dtype: int64,
#  Class
#  0    21968
#  1       32
#  Name: count, dtype: int64,
#  Class
#  0    22770
#  1       37
#  Name: count, dtype: int64)

# %%
print(val[val['Class'] == 1].shape)
print(test[test['Class'] == 1].shape)
print(train[train['Class'] == 1].shape)
# Out:
# (37, 31)
# (32, 31)
# (423, 31)

# %%
train_np, test_np, val_np = train.to_numpy(), test.to_numpy(), val.to_numpy()
train_np.shape, test_np.shape, val_np.shape
# Out:
# ((240000, 31), (22000, 31), (22807, 31))

# %%
x_train, y_train = train_np[:, :-1], train_np[:, -1]
x_test, y_test = test_np[:, :-1], test_np[:, -1]
x_val, y_val = val_np[:, :-1], val_np[:, -1]
x_train.shape, y_train.shape, x_test.shape, y_test.shape, x_val.shape, y_val.shape
# Out:
# ((240000, 30), (240000,), (22000, 30), (22000,), (22807, 30), (22807,))

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression()
logistic_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
logistic_model.score(x_test, y_test)
# Out:
# 0.9994090909090909

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_val, logistic_model.predict(x_val)))
# Out:
# [[22764     6]
#  [    9    28]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, logistic_model.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22770
#        Fraud       0.82      0.76      0.79        37
#
#     accuracy                           1.00     22807
#    macro avg       0.91      0.88      0.89     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
not_frauds = new_df.query('Class == 0')
frauds = new_df.query('Class == 1')
not_frauds['Class'].value_counts(), frauds['Class'].value_counts()
# Out:
# (Class
#  0    284315
#  Name: count, dtype: int64,
#  Class
#  1    492
#  Name: count, dtype: int64)

# %%
balanced_df = pd.concat([frauds, not_frauds.sample(len(frauds), random_state=1)])
balanced_df['Class'].value_counts()
# Out:
# Class
# 1    492
# 0    492
# Name: count, dtype: int64

# %%
balanced_df = balanced_df.sample(frac=1, random_state=1)
balanced_df
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 262274  0.928243   1.897000  -0.382903  -0.937501   0.397453  -0.099581
# 6108    0.040430  -4.397974   1.358367  -2.592844   2.679787  -1.128131
# 154670  0.593135  -2.296987   4.064043  -5.957706   4.680008  -2.080938
# 4405    0.021801  -0.908649   0.225291   2.065207  -1.619825  -0.243570
# 13039   0.132535   1.293398  -0.741447   1.290535  -0.460381  -1.330159
# ...          ...        ...        ...        ...        ...        ...
# 75845   0.325692   0.776239  -2.159076   0.166790  -1.032230  -2.005697
# 42635   0.238327  -7.334341   4.960892  -8.451410   8.174825  -7.237464
# 105702  0.403109   1.256199  -0.015231  -1.469229  -0.093911   2.128520
# 45732   0.245810  -3.843009   3.375110  -5.492893   6.136378   2.797195
# 154587  0.590965 -28.255053  21.467203 -26.871339  11.737436 -17.999630
#
#               V6         V7         V8         V9  ...        V21       V22  \
# 262274 -0.147026  -0.235360   0.028097   0.502655  ...   0.044393  0.114087
# 6108   -1.706536  -3.496197  -0.248778  -0.247768  ...   0.573574  0.176968
# 154670 -1.463272  -4.490847   1.029246  -1.593249  ...   1.089084  0.975398
# 4405   -0.543429   0.112440   0.029091  -0.001948  ...  -0.185273 -0.489357
# 13039   0.323910  -1.463370   0.237573   0.988569  ...   0.225547  0.976518
# ...          ...        ...        ...        ...  ...        ...       ...
# 75845  -0.875764  -0.459015  -0.303511  -1.853996  ...  -0.225784 -1.185930
# 42635  -2.382711 -11.508842   4.635798  -6.557760  ...   2.153755  0.033922
# 105702  3.459439  -0.660356   0.902599   0.461278  ...  -0.234142 -0.584964
# 45732  -2.646162  -1.668931  -2.617552  -3.945843  ...  -1.277812  0.719652
# 154587  6.065901 -41.506796 -38.987263 -13.434066  ... -21.453736  8.361985
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 262274  0.217178  0.723793 -0.250976  0.171696 -0.054108 -0.049019  0.403829
# 6108   -0.436207 -0.053502  0.252405 -0.657488 -0.827136  0.849573  0.517013
# 154670 -0.625530 -0.535181  0.247435  0.160400  0.969582  0.335041  1.145812
# 4405    0.000478 -0.029892  0.219936 -0.556919  0.238088  0.120712  0.298330
# 13039  -0.061274 -0.002657  0.320648 -0.069984  0.035146  0.002897 -0.307413
# ...          ...       ...       ...       ...       ...       ...       ...
# 75845  -0.118613  0.330211 -0.028764 -0.520507 -0.037676  0.093892  5.184098
# 42635  -0.014095  0.625250 -0.053390  0.164709  1.411047  0.315645 -0.148397
# 105702 -0.130329  0.941959  0.706134  0.426656  0.003528  0.036224 -0.135401
# 45732   0.451125 -0.258094  0.656129  0.556676  0.739383 -0.203050 -0.293440
# 154587  4.909111  0.098328 -1.508739  0.008711 -5.407824 -0.183811 -0.307413
#
#         Class
# 262274      0
# 6108        1
# 154670      1
# 4405        0
# 13039       0
# ...       ...
# 75845       0
# 42635       1
# 105702      0
# 45732       1
# 154587      1
#
# [984 rows x 31 columns]

# %%
balanced_df_np = balanced_df.to_numpy()

x_train_b, y_train_b = balanced_df_np[:700, :-1], balanced_df_np[:700, -1].astype(int)
x_test_b, y_test_b = balanced_df_np[700:842, :-1], balanced_df_np[700:842, -1].astype(int)
x_val_b, y_val_b = balanced_df_np[842:, :-1], balanced_df_np[842:, -1].astype(int)
x_train_b.shape, y_train_b.shape, x_test_b.shape, y_test_b.shape, x_val_b.shape, y_val_b.shape
# Out:
# ((700, 30), (700,), (142, 30), (142,), (142, 30), (142,))

# %%
logistic_model_b = LogisticRegression(class_weight='balanced')
logistic_model_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, logistic_model_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.92      0.96      0.94        72
#        Fraud       0.96      0.91      0.93        70
#
#     accuracy                           0.94       142
#    macro avg       0.94      0.94      0.94       142
# weighted avg       0.94      0.94      0.94       142
